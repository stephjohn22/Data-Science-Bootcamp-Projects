# %% [markdown]
# # Machine Learning

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     | Justification     |
# | ---- | ----------- | ---------  | ---------  |
# | 1.1  |Sensor data from the car's cameras, radar and GPS. E.g A picture taken from a car's camera showing the road ahead|Control commands for the car's steering, acceleration and braking systems|The self-driving car uses sensor data to understand its surroundings, detect obstacles and decide how to move safely and efficiently. The inputs are real-time data from various sensors. The outputs are the commands that control the car's steering, acceleration and braking.|
# | 1.2  |User's viewing history, ratings and preferences|Personalised  movie or TV show recommendations for the user|The Netflix recommendation system uses data about users' past behaviour and preferences to predict what other content they might like. The inputs are data points from the user's interactions with the platform. The output is a list of recommended shows and films tailored to the user's tastes.|
# | 1.3  |An image or digital capture of a person's signature|A verification result indicating whether the signature is genuine or forged|Signature recognition systems compare a given signature to a stored reference to verify its authenticity. The input is the signature to be checked and the output is a result indicating whether the signature is valid.|
# | 1.4  |Patient's medical data, including symptoms, medical history, lab test results and imaging scans|A diagnosis or list of potential conditions, along with recommended treatment options|Medical diagnosis systems analyse patient data to identify possible conditions and suggest treatments. The inputs include various types of medical data that give a full picture of the patient's health. The outputs are the diagnostic results and treatment recommendations based on the analysed data.|

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1
#
# Classification: Emails are categorised into distinct classes.
# * 2.2
#
# Regression: The stock price is a continuous numerical value being predicted
# * 2.3
#
# Classification: Each of the images are assigned to a specific animal species category
# * 2.4
#
# Classisification: The outcome is catergorical (presence or absence of a disease)

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1
#
# Unsupervised: Identifies unusual patterns in data without labeled examples
# * 3.2
#
# Supervised: Learning patterns from historical data will be used to make predictions about future values
# * 3.3
#
# Unsupervised: Labeled data is not requires to segemnting the customer demographics
# * 3.4
#
# Unsupervised: Posts can still be catergorised by identifying underlying themes or topics in the posts without the use of labeled data

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# *4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1
#
# It may not be neccessary to use semi-supervised learning as there is sufficient amount of labeled data available. If the dataset is large and there is a very high amount of unlabeled data semi-supervised learning should be used to potentially improve model performance.
#
# * 4.2
#
# Semi-supervised learning can be used as there is a small portion of labeled data. It will enhance the model's predicitve capabilities.
# * 4.3
#
# Semi-supervised learning may not be needed as the majority of emails are labeled. If there is uncertainty in the labeling, semi-supervised learning could be explored to leverage the abundance of unlabeled data to potentially improve the model's performance.
# * 4.4
#
# Predicting the probability of default typically relies on historical data that is labeled with outcomes. Therefore semi-supervised learning is not neccessary with a sufficient amount of labeled data.
